# %% [markdown]
# <img src='logo_ucm.png' width='200'/>

# %% [markdown]
# # <center>PROYECTO MACHINE LEARNING AIRBNB</center>

# %% [markdown]
# **PARTICIPANTES:**

# %% [markdown]
# PROYECTO MACHINE LEARNING AIRBNB
# PARTICIPANTES:
#
# BRYAM DAVID CHAMBA JARAMILLO
#
# ALVAR YEBEL DE BLAS FERNÁNDEZ
#
# MARÍA GARCÍA RODRIGUEZ
#
# MANUEL GRAU ROLDÁN
#
# ÁLVARO MARTÍN LÓPEZ
#
# LUIS JAVIER NATES ARECHAVALETA

# %%
import funciones_auxiliares 
import matplotlib.pyplot as plt


import numpy as np
import pandas as pd
import datetime

#Estadística
from scipy import stats
from scipy.stats import norm
import inspect

#Aprendizaje automático
from sklearn.impute import SimpleImputer
from sklearn import preprocessing

# %%
data = pd.read_csv('airbnb-listings-extract.csv', sep=';', error_bad_lines=False)
# Out:
# C:\Users\lolo\AppData\Local\Temp/ipykernel_7464/828998556.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('airbnb-listings-extract.csv', sep=';', error_bad_lines=False)

# %%
data.shape
# Out:
# (14780, 89)

# %%
data.describe()
# Out:
#                  ID     Scrape ID       Host ID  Host Response Rate  \
# count  1.478000e+04  1.478000e+04  1.478000e+04        12881.000000
# mean   1.028089e+07  2.017037e+13  3.608080e+07           94.823461
# std    5.564829e+06  5.667971e+08  3.425360e+07           15.215988
# min    1.862800e+04  2.016010e+13  1.745300e+04            0.000000
# 25%    5.554732e+06  2.017041e+13  6.787360e+06          100.000000
# 50%    1.133492e+07  2.017041e+13  2.464875e+07          100.000000
# 75%    1.532631e+07  2.017041e+13  5.432919e+07          100.000000
# max    1.910969e+07  2.017062e+13  1.247534e+08          100.000000
#
#        Host Listings Count  Host Total Listings Count      Latitude  \
# count         14777.000000               14777.000000  14780.000000
# mean             12.513636                  12.513636     40.497626
# std              34.090223                  34.090223      4.641387
# min               0.000000                   0.000000    -37.851182
# 25%               1.000000                   1.000000     40.409726
# 50%               2.000000                   2.000000     40.419466
# 75%               6.000000                   6.000000     40.430916
# max             519.000000                 519.000000     55.966912
#
#           Longitude  Accommodates     Bathrooms  ...  Number of Reviews  \
# count  14780.000000  14780.000000  14725.000000  ...       14780.000000
# mean      -3.858041      3.277808      1.281732  ...          22.632273
# std       14.123146      2.097291      0.658517  ...          38.290244
# min     -123.131344      1.000000      0.000000  ...           0.000000
# 25%       -3.707604      2.000000      1.000000  ...           1.000000
# 50%       -3.700785      3.000000      1.000000  ...           7.000000
# 75%       -3.684057      4.000000      1.000000  ...          27.000000
# max      153.371427     16.000000      8.000000  ...         446.000000
#
#        Review Scores Rating  Review Scores Accuracy  \
# count          11476.000000            11454.000000
# mean              91.697978                9.416012
# std                8.989101                0.921938
# min               20.000000                2.000000
# 25%               89.000000                9.000000
# 50%               94.000000               10.000000
# 75%               98.000000               10.000000
# max              100.000000               10.000000
#
#        Review Scores Cleanliness  Review Scores Checkin  \
# count               11460.000000           11443.000000
# mean                    9.328883               9.621778
# std                     0.989933               0.802736
# min                     2.000000               2.000000
# 25%                     9.000000               9.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        Review Scores Communication  Review Scores Location  \
# count                 11460.000000            11440.000000
# mean                      9.647033                9.532168
# std                       0.767116                0.774527
# min                       2.000000                2.000000
# 25%                       9.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        Review Scores Value  Calculated host listings count  Reviews per Month
# count         11439.000000                    14776.000000       11618.000000
# mean              9.218201                        9.486871           1.870014
# std               0.950578                       23.626014           1.867550
# min               2.000000                        1.000000           0.020000
# 25%               9.000000                        1.000000           0.450000
# 50%               9.000000                        2.000000           1.200000
# 75%              10.000000                        5.000000           2.780000
# max              10.000000                      145.000000          17.210000
#
# [8 rows x 36 columns]

# %%
data.isna().mean()
# Out:
# ID                                0.000000
# Listing Url                       0.000000
# Scrape ID                         0.000000
# Last Scraped                      0.000000
# Name                              0.000068
#                                     ...
# Cancellation Policy               0.000000
# Calculated host listings count    0.000271
# Reviews per Month                 0.213938
# Geolocation                       0.000000
# Features                          0.000068
# Length: 89, dtype: float64

# %%
lista_fuera = []
for i in data.columns:
    if data[i].isna().sum() > 0.3*len(data.index):
        lista_fuera.append(i)
data = data.drop(columns=lista_fuera)

# %%
data.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  11210388  https://www.airbnb.com/rooms/11210388  20170306202425
# 1  17471131  https://www.airbnb.com/rooms/17471131  20170407214050
# 2  17584891  https://www.airbnb.com/rooms/17584891  20170407214050
# 3   5398030   https://www.airbnb.com/rooms/5398030  20170407214050
# 4  18104606  https://www.airbnb.com/rooms/18104606  20170407214050
#
#   Last Scraped                                 Name  \
# 0   2017-03-07       The Loft-Full Bath-Deck w/View
# 1   2017-04-08           Claris I, Friendly Rentals
# 2   2017-04-08  Style Terrace Red, Friendly Rentals
# 3   2017-04-08    Picasso Suite 1.4 Paseo de Gracia
# 4   2017-04-08       Smart City Centre Apartment II
#
#                                              Summary  \
# 0  Loft in the Hill country 12-15 minutes directl...
# 1  This apartment has: 1 double bed, 1 double sof...
# 2  This apartment has: 1 double bed, 1 double sof...
# 3  Live like a local in Barcelona's most chic dis...
# 4  Unique apartment in vibrant neighborhoods, car...
#
#                                                Space  \
# 0  This loft has a spectacular view of the hills ...
# 1  This apartment has: 1 double bed, 1 double sof...
# 2  This apartment has: 1 double bed, 1 double sof...
# 3  You wake up to the sun rising over Barcelona's...
# 4  License: HUTB-005313 Charming apartment, locat...
#
#                                          Description Experiences Offered  \
# 0  Loft in the Hill country 12-15 minutes directl...                none
# 1  This apartment has: 1 double bed, 1 double sof...                none
# 2  This apartment has: 1 double bed, 1 double sof...                none
# 3  Live like a local in Barcelona's most chic dis...                none
# 4  Unique apartment in vibrant neighborhoods, car...                none
#
#                                        Thumbnail Url  ...  \
# 0  https://a0.muscache.com/im/pictures/c351a9b5-5...  ...
# 1  https://a0.muscache.com/im/pictures/3ce27aee-f...  ...
# 2  https://a0.muscache.com/im/pictures/fd4528f3-f...  ...
# 3  https://a0.muscache.com/im/pictures/77343485/3...  ...
# 4  https://a0.muscache.com/im/pictures/d26f6f1b-f...  ...
#
#   Review Scores Cleanliness Review Scores Checkin Review Scores Communication  \
# 0                      10.0                  10.0                        10.0
# 1                      10.0                  10.0                        10.0
# 2                       NaN                   NaN                         NaN
# 3                       9.0                  10.0                        10.0
# 4                       NaN                   NaN                         NaN
#
#    Review Scores Location Review Scores Value Cancellation Policy  \
# 0                    10.0                10.0            moderate
# 1                     8.0                10.0     super_strict_30
# 2                     NaN                 NaN     super_strict_30
# 3                    10.0                 9.0              strict
# 4                     NaN                 NaN            flexible
#
#   Calculated host listings count Reviews per Month  \
# 0                            1.0              3.50
# 1                          106.0              0.86
# 2                          106.0               NaN
# 3                           24.0              1.09
# 4                           92.0               NaN
#
#                     Geolocation  \
# 0  30.3373609355,-97.8632766782
# 1   41.3896829422,2.17262543017
# 2   41.3930345489,2.16217327868
# 3    41.3969668101,2.1674178103
# 4   41.3886851936,2.15514963616
#
#                                             Features
# 0  Host Is Superhost,Host Has Profile Pic,Host Id...
# 1  Host Has Profile Pic,Requires License,Instant ...
# 2  Host Has Profile Pic,Requires License,Instant ...
# 3  Host Has Profile Pic,Host Identity Verified,Re...
# 4  Host Has Profile Pic,Host Identity Verified,Is...
#
# [5 rows x 72 columns]

# %%
data = data.drop(['Listing Url', 'Name','Scrape ID', 'Last Scraped','Summary','Space','Description','Thumbnail Url',
                  'Medium Url','Picture Url','XL Picture Url','Thumbnail Url','Host Thumbnail Url', 'Host Location',
                  'Geolocation','Features','Host URL', 'Host Picture Url','Host Name','First Review', 'Last Review','Host Verifications'], axis = 1)
#

# %% [markdown]
# Podemos eliminar también algunas de las referencias a la localización de los airbnb, ya que son datos redundantes y con la longitud y la latitud, en principio, puede valernos

# %%
data = data.drop(['Zipcode','Street', 'Neighbourhood Group Cleansed', 'City', 'State', 'Market', 'Smart Location',
                  'Country Code', 'Country','Host Neighbourhood'], axis=1)

# %%
data.head()
# Out:
#          ID Experiences Offered    Host ID  Host Since Host Response Time  \
# 0  11210388                none   58386783  2016-02-11     within an hour
# 1  17471131                none  102947901  2016-11-08     within an hour
# 2  17584891                none  102947901  2016-11-08     within an hour
# 3   5398030                none     131794  2010-05-25     within an hour
# 4  18104606                none   54310958  2016-01-12     within an hour
#
#    Host Response Rate  Host Listings Count  Host Total Listings Count  \
# 0               100.0                  1.0                        1.0
# 1               100.0                162.0                      162.0
# 2               100.0                162.0                      162.0
# 3               100.0                 27.0                       27.0
# 4                99.0                207.0                      207.0
#
#             Neighbourhood Cleansed   Latitude  ...  Review Scores Rating  \
# 0                            78733  30.337361  ...                  98.0
# 1           la Dreta de l'Eixample  41.389683  ...                  80.0
# 2           la Dreta de l'Eixample  41.393035  ...                   NaN
# 3           la Dreta de l'Eixample  41.396967  ...                  92.0
# 4  l'Antiga Esquerra de l'Eixample  41.388685  ...                   NaN
#
#   Review Scores Accuracy Review Scores Cleanliness  Review Scores Checkin  \
# 0                   10.0                      10.0                   10.0
# 1                    8.0                      10.0                   10.0
# 2                    NaN                       NaN                    NaN
# 3                   10.0                       9.0                   10.0
# 4                    NaN                       NaN                    NaN
#
#    Review Scores Communication  Review Scores Location  Review Scores Value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                     8.0                 10.0
# 2                          NaN                     NaN                  NaN
# 3                         10.0                    10.0                  9.0
# 4                          NaN                     NaN                  NaN
#
#   Cancellation Policy Calculated host listings count  Reviews per Month
# 0            moderate                            1.0               3.50
# 1     super_strict_30                          106.0               0.86
# 2     super_strict_30                          106.0                NaN
# 3              strict                           24.0               1.09
# 4            flexible                           92.0                NaN
#
# [5 rows x 41 columns]

# %%
data.dtypes
# Out:
# ID                                  int64
# Experiences Offered                object
# Host ID                             int64
# Host Since                         object
# Host Response Time                 object
# Host Response Rate                float64
# Host Listings Count               float64
# Host Total Listings Count         float64
# Neighbourhood Cleansed             object
# Latitude                          float64
# Longitude                         float64
# Property Type                      object
# Room Type                          object
# Accommodates                        int64
# Bathrooms                         float64
# Bedrooms                          float64
# Beds                              float64
# Bed Type                           object
# Amenities                          object
# Price                             float64
# Guests Included                     int64
# Extra People                        int64
# Minimum Nights                      int64
# Maximum Nights                      int64
# Calendar Updated                   object
# Availability 30                     int64
# Availability 60                     int64
# Availability 90                     int64
# Availability 365                    int64
# Calendar last Scraped              object
# Number of Reviews                   int64
# Review Scores Rating              float64
# Review Scores Accuracy            float64
# Review Scores Cleanliness         float64
# Review Scores Checkin             float64
# Review Scores Communication       float64
# Review Scores Location            float64
# Review Scores Value               float64
# Cancellation Policy                object
# Calculated host listings count    float64
# Reviews per Month                 float64
# dtype: object

# %% [markdown]
# Variable a predecir, la llamaremos y para realizar luego la regresión sobre ella

# %%
y = data['Price']

# %% [markdown]
# Creamos listas que contentgan los nombres de las variables a estudiar dependiendo su tipo

# %%
list_var_continuous = list(data.select_dtypes('float').columns)
list_var_discrets = list(data.select_dtypes('O').columns)

data[list_var_discrets]
# Out:
#       Experiences Offered  Host Since  Host Response Time  \
# 0                    none  2016-02-11      within an hour
# 1                    none  2016-11-08      within an hour
# 2                    none  2016-11-08      within an hour
# 3                    none  2010-05-25      within an hour
# 4                    none  2016-01-12      within an hour
# ...                   ...         ...                 ...
# 14775                none  2013-12-18  within a few hours
# 14776                none  2017-03-24                 NaN
# 14777                none  2015-07-06      within an hour
# 14778                none  2013-03-20  within a few hours
# 14779                none  2014-04-21      within an hour
#
#                 Neighbourhood Cleansed    Property Type        Room Type  \
# 0                                78733             Loft  Entire home/apt
# 1               la Dreta de l'Eixample        Apartment  Entire home/apt
# 2               la Dreta de l'Eixample        Apartment  Entire home/apt
# 3               la Dreta de l'Eixample        Apartment  Entire home/apt
# 4      l'Antiga Esquerra de l'Eixample        Apartment  Entire home/apt
# ...                                ...              ...              ...
# 14775               Bedford-Stuyvesant        Apartment  Entire home/apt
# 14776                        Vaugirard  Bed & Breakfast     Private room
# 14777              Batignolles-Monceau        Apartment  Entire home/apt
# 14778                   City Park West        Apartment  Entire home/apt
# 14779                          Ravenna            House     Private room
#
#        Bed Type                                          Amenities  \
# 0      Real Bed  TV,Cable TV,Internet,Wireless Internet,Air con...
# 1      Real Bed  Wireless Internet,Air conditioning,Elevator in...
# 2      Real Bed  Wireless Internet,Air conditioning,Elevator in...
# 3      Real Bed  TV,Internet,Wireless Internet,Air conditioning...
# 4      Real Bed  TV,Wireless Internet,Air conditioning,Kitchen,...
# ...         ...                                                ...
# 14775  Real Bed  TV,Cable TV,Internet,Wireless Internet,Air con...
# 14776  Real Bed  TV,Wireless Internet,Kitchen,Breakfast,Elevato...
# 14777  Real Bed  TV,Cable TV,Internet,Wireless Internet,Air con...
# 14778  Real Bed  Internet,Wireless Internet,Kitchen,Heating,Was...
# 14779  Real Bed  TV,Cable TV,Internet,Wireless Internet,Air Con...
#
#       Calendar Updated Calendar last Scraped Cancellation Policy
# 0                today            2017-03-06            moderate
# 1                today            2017-04-08     super_strict_30
# 2                today            2017-04-08     super_strict_30
# 3                today            2017-04-08              strict
# 4                today            2017-04-08            flexible
# ...                ...                   ...                 ...
# 14775       5 days ago            2017-05-02              strict
# 14776       3 days ago            2017-04-06            flexible
# 14777       5 days ago            2017-04-05              strict
# 14778        yesterday            2016-05-18            moderate
# 14779      3 weeks ago            2016-01-04            flexible
#
# [14780 rows x 11 columns]

# %% [markdown]
# Hagamos la matriz de correlación para ver si algunas variables aportan información similar a nuestro modelo de regresión, lo que permitiría eliminar algunas variables

# %% [markdown]
# 1. Primero rellenemos los valores missing imputándolos por el método KNN Imputer

# %%
funciones_auxiliares.get_corr_matrix(dataset = data[list_var_continuous], metodo='spearman', size_figure=[10,8])
# Out:
# 0

# %% [markdown]
# Con un simple análisis cualitativo parece claro que 3 variables (las relacionadas tienen una correlaión perfecta por lo que podemos prescindir e dos de ellas y simplificar algo el modelo

# %%
data = data.drop(['Host Total Listings Count', 'Calculated host listings count'], axis = 1)
data = data.drop(['Availability 30','Availability 60','Availability 365'], axis = 1)

# %%
#Eliminamos estos datos porque tienen un significado parecido y una alta correspondencia
data = data.drop([ 'Review Scores Cleanliness', 'Review Scores Rating', 'Review Scores Accuracy','Review Scores Checkin',
       'Review Scores Communication', 'Review Scores Location'], axis = 1)

# %%
data.columns
# Out:
# Index(['ID', 'Experiences Offered', 'Host ID', 'Host Since',
#        'Host Response Time', 'Host Response Rate', 'Host Listings Count',
#        'Neighbourhood Cleansed', 'Latitude', 'Longitude', 'Property Type',
#        'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms', 'Beds',
#        'Bed Type', 'Amenities', 'Price', 'Guests Included', 'Extra People',
#        'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Availability 90', 'Calendar last Scraped', 'Number of Reviews',
#        'Review Scores Value', 'Cancellation Policy', 'Reviews per Month'],
#       dtype='object')

# %%
data.select_dtypes('object').columns
# Out:
# Index(['Experiences Offered', 'Host Since', 'Host Response Time',
#        'Neighbourhood Cleansed', 'Property Type', 'Room Type', 'Bed Type',
#        'Amenities', 'Calendar Updated', 'Calendar last Scraped',
#        'Cancellation Policy'],
#       dtype='object')

# %% [markdown]
# ## Valores missing e imputación

# %% [markdown]
# 1. Primero las variables continuas

# %%
list_var_continuous = list(data.select_dtypes('float').columns)

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(data[list_var_continuous])
data[list_var_continuous]=imputer.transform(data[list_var_continuous])

# %% [markdown]
# 2. Comencemos con el tiempo que suele tardar el anfitrión en contestar a los mensajes de los posibles clientes
# Utilizaremos los cuantiles para poder distibuir los valores en cuatro categorías

# %%
data['Host Response Time'] = data['Host Response Time'].fillna(0)

data['Host Response Time'].value_counts(normalize=True)\
                .mul(100).rename('percent').reset_index()
# Out:
#                 index    percent
# 0      within an hour  53.484438
# 1  within a few hours  19.431664
# 2                   0  12.848444
# 3        within a day  12.192152
# 4  a few days or more   2.043302

# %%
data['Host Response Time'] = data['Host Response Time'].replace({'within an hour': 0.75, 'within a few hours':0.5, 'within a day': 0.25, 'a few days or more': 0.0}).astype('float')

# %% [markdown]
# Rellenamos los valores de Host Response Rate

# %%
data['Host Response Time'] = data['Host Response Time'].fillna(0)

# %% [markdown]
# Póliza de cancelación

# %%
data['Cancellation Policy'].value_counts()
# Out:
# strict             5742
# flexible           4671
# moderate           4248
# strict_new           34
# super_strict_60      32
# moderate_new         20
# super_strict_30      19
# flexible_new         14
# Name: Cancellation Policy, dtype: int64

# %%
data['Cancellation Policy'] = data['Cancellation Policy'].replace({'strict': 0.25, 'flexible':0.9, 'moderate': 0.5,
                                                                   'strict_new': 0.25, 'super_strict_60':0, 'super_strict_30':0,
                                                                  'moderate_new':0.5, 'flexible_new': 0.9}).astype('float')

# %% [markdown]
# Al estandarizar los datos con la división del X_train y X_test servirán para mejorar el algoritmo

# %% [markdown]
# 3. El siguiente paso será transformar la fecha desde la que el dueño del airbnb ofrece un alojamiento en días desde esa fecha

# %%
fecha = pd.to_datetime(data['Host Since'])
#Creamos una variable que reste la actualidad (3/6/2022) a la fecha del anfitrión 
#Nota para eliminar, esto es igual que en big data
tiempo_anfitrión = (pd.datetime(2022, 6, 3) - fecha).astype('timedelta64[D]')
#Sustituimos por la variable fecha para que sea más sencillo utilizarla a la hora de los modelos 
data['Tiempo Anfitrión Días'] = tiempo_anfitrión
data['Tiempo Anfitrión Días'] = data['Tiempo Anfitrión Días'].fillna(0)

data = data.drop('Host Since',axis = 1)
# Out:
# C:\Users\Luis\AppData\Local\Temp/ipykernel_17000/4719177.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   tiempo_anfitrión = (pd.datetime(2022, 6, 3) - fecha).astype('timedelta64[D]')

# %% [markdown]
# Vayamos con el número de comodidades o 'Amenitites'.
#
# Tendremos en cuenta el número a la hora de valorar el precio de un alojamiento

# %%
data['Amenities'] = data['Amenities'].fillna(0)

lista = []
amenities = []
i= 0
while i < len(data['Amenities']):
    if type(data['Amenities'][i]) != int:
        juntos =data['Amenities'][i].split(',')
        l = len(data['Amenities'][i].split(','))
        i=i+1
    else:
        i=i+1
    lista.append(l) 
    amenities.append(juntos)
data['nº Amenities'] = lista

# %% [markdown]
# Ahora valoraremos las comodidades menos frecuentes para darles un valor extra

# %%
dic = {}
for i in range(0,len(amenities)):
    for j in range(0,len(amenities[i])):
        if amenities[i][j] not in dic.keys():
            dic[amenities[i][j]] = 1
        else:
            dic[amenities[i][j]] = dic[amenities[i][j]] +1

# %%
dic_min = {}
dic_exclusive = {}
for i in dic:
    if dic[i] < len(data)/10:
        dic_min[dic[i]] = dic[i]
        if dic[i] <len(data)/50:
            dic_exclusive[dic[i]] = dic[i]

# %% [markdown]
# Property Type

# %%
data['Property Type'].value_counts()
# Out:
# Apartment             11962
# House                  1368
# Condominium             363
# Bed & Breakfast         353
# Loft                    305
# Other                   225
# Dorm                     44
# Guesthouse               42
# Chalet                   26
# Villa                    19
# Townhouse                17
# Hostel                   16
# Serviced apartment       13
# Boutique hotel            6
# Boat                      4
# Camper/RV                 4
# Guest suite               3
# Casa particular           3
# Earth House               3
# Bungalow                  2
# Tent                      1
# Timeshare                 1
# Name: Property Type, dtype: int64

# %%
data['Property Type'].replace({
    'Townhouse': 'House',
    'Serviced apartment': 'Apartment',
    'Loft': 'Apartment',
    'Bungalow': 'House',
    'Guesthouse': 'House',
    'Casa particular': 'House',
    'Cottage': 'House',
    'Villa': 'House',
    'Tiny house': 'House',
    'Earth House': 'House',
    'Chalet': 'House',
    'Boutique hotel': 'Other',
    'Condominium': 'Other',
    'Bed & Breakfast': 'Other',
    'Dorm': 'Other',
    'Hostel': 'Other',
    'Guest suite': 'Other',
    'Tent': 'Other',
    'Timeshare': 'Other',
    'Boat': 'Other',
    'Camper/RV': 'Other'
    }, inplace=True)

# %% [markdown]
# ## Distribución de pisos en cuanto al precio (variable a estimar)

# %%
plt.figure(figsize=(20,4))
data['Price'].hist(bins=100, range=(0,max(data['Price'])))
plt.margins(x=0)
plt.axvline(200, color='red', linestyle='--')
plt.title("Número de Airbnb por precio", fontsize=16)
plt.xlabel("Precio ")
plt.ylabel("Número de Airbnb")
plt.show()

# %% [markdown]
# La mayor parte de los pisos tiene un precio menor de 200, solo unos pocos tienen un precio por encima de ese valor

# %%
plt.figure(figsize=(20,5))
data.groupby('nº Amenities').Price.mean().plot(kind='bar')
plt.title('Precio Medio respecto al número de comodidades', fontsize=14)
plt.xlabel('Número de comodidades', fontsize=13)
plt.ylabel('Precio Medio ', fontsize=13)
plt.xticks(rotation=0)
plt.xlim(left=0.5)
plt.show()

# %% [markdown]
# No parece ser un factor muy importante, aunque sí crece poco a poco. el Dato de las 33 es algo completamente aleatorio, es posible que solo haya un dato con 33 'Amenities'
