# %% [markdown]
# <img src='logo_ucm.png' width='200'/>

# %% [markdown]
# # <center>PROYECTO MACHINE LEARNING AIRBNB</center>

# %% [markdown]
# **PARTICIPANTES:**

# %% [markdown]
# BRYAM DAVID CHAMBA JARAMILLO
#
# ALVAR YEBEL DE BLAS FERNÁNDEZ
#
# MARÍA GARCÍA RODRÍGUEZ
#
# MANUEL GRAU ROLDÁN
#
# ÁLVARO MARTÍN LÓPEZ
#
# LUIS JAVIER NATES ARECHAVALETA

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('airbnb-listings-extract.csv', sep=';', error_bad_lines=False)
# Out:
# C:\Users\lolo\AppData\Local\Temp/ipykernel_4676/828998556.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('airbnb-listings-extract.csv', sep=';', error_bad_lines=False)

# %%
data
# Out:
#              ID                            Listing Url       Scrape ID  \
# 0      11210388  https://www.airbnb.com/rooms/11210388  20170306202425
# 1      17471131  https://www.airbnb.com/rooms/17471131  20170407214050
# 2      17584891  https://www.airbnb.com/rooms/17584891  20170407214050
# 3       5398030   https://www.airbnb.com/rooms/5398030  20170407214050
# 4      18104606  https://www.airbnb.com/rooms/18104606  20170407214050
# ...         ...                                    ...             ...
# 14775   2098030   https://www.airbnb.com/rooms/2098030  20170502132028
# 14776  17989442  https://www.airbnb.com/rooms/17989442  20170404145355
# 14777  13278634  https://www.airbnb.com/rooms/13278634  20170404145355
# 14778  10733941  https://www.airbnb.com/rooms/10733941  20160516142622
# 14779   4637801   https://www.airbnb.com/rooms/4637801  20160104002432
#
#       Last Scraped                                         Name  \
# ...

# %%
data.dtypes
# Out:
# Last Scraped                       object
# Experiences Offered                object
# Transit                            object
# Access                             object
# House Rules                        object
#                                    ...
# Cancellation Policy                object
# Calculated host listings count    float64
# Reviews per Month                 float64
# Geolocation                        object
# Features                           object
# Length: 71, dtype: object

# %%
data=data.drop(['ID','Scrape ID','Scrape ID'\
           ,'Listing Url','Name','Summary'\
           ,'Space','Description','Notes',
          'Neighborhood Overview','Picture Url',
          'Interaction','Thumbnail Url','Medium Url'
          ,'XL Picture Url','Host ID',
          'Host URL','Host About','Host Location'],axis=1)

# %%
features=data['Features']

# %%
data.isna().mean()
# Out:
# Last Scraped                      0.000000
# Experiences Offered               0.000000
# Transit                           0.386604
# Access                            0.437212
# House Rules                       0.349188
#                                     ...
# Cancellation Policy               0.000000
# Calculated host listings count    0.000271
# Reviews per Month                 0.213938
# Geolocation                       0.000000
# Features                          0.000068
# Length: 71, dtype: float64

# %%
lista_fuera = []
for i in data.columns:
    if data[i].isna().sum() > 0.3*len(data.index):
        lista_fuera.append(i)
data = data.drop(columns=lista_fuera)

# %%
data.shape
# Out:
# (14780, 72)

# %%
data.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  11210388  https://www.airbnb.com/rooms/11210388  20170306202425
# 1  17471131  https://www.airbnb.com/rooms/17471131  20170407214050
# 2  17584891  https://www.airbnb.com/rooms/17584891  20170407214050
# 3   5398030   https://www.airbnb.com/rooms/5398030  20170407214050
# 4  18104606  https://www.airbnb.com/rooms/18104606  20170407214050
#
#   Last Scraped                                 Name  \
# 0   2017-03-07       The Loft-Full Bath-Deck w/View
# 1   2017-04-08           Claris I, Friendly Rentals
# 2   2017-04-08  Style Terrace Red, Friendly Rentals
# 3   2017-04-08    Picasso Suite 1.4 Paseo de Gracia
# 4   2017-04-08       Smart City Centre Apartment II
#
#                                              Summary  \
# 0  Loft in the Hill country 12-15 minutes directl...
# 1  This apartment has: 1 double bed, 1 double sof...
# 2  This apartment has: 1 double bed, 1 double sof...
# ...

# %%
data.columns
# Out:
# Index(['Last Scraped', 'Experiences Offered', 'Transit', 'Access',
#        'House Rules', 'Host Name', 'Host Since', 'Host Response Time',
#        'Host Response Rate', 'Host Acceptance Rate', 'Host Picture Url',
#        'Host Neighbourhood', 'Host Listings Count',
#        'Host Total Listings Count', 'Host Verifications', 'Street',
#        'Neighbourhood', 'Neighbourhood Cleansed',
#        'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
#        'Smart Location', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Beds', 'Bed Type', 'Amenities', 'Square Feet', 'Price', 'Weekly Price',
#        'Monthly Price', 'Security Deposit', 'Cleaning Fee', 'Guests Included',
#        'Extra People', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Has Availability', 'Availability 30', 'Availability 60',
# ...

# %%
data=data.drop(['ID','Scrape ID','Scrape ID'\
           ,'Listing Url','Name','Summary'\
           ,'Space','Description','Notes',
          'Neighborhood Overview','Picture Url',
          'Interaction','Thumbnail Url','Medium Url'
          ,'XL Picture Url','Host ID',
          'Host URL','Host About','Host Location','Host Thumbnail Url'],axis=1)

# %%
data.dtypes
# Out:
# Last Scraped                       object
# Experiences Offered                object
# Transit                            object
# Access                             object
# House Rules                        object
#                                    ...
# Cancellation Policy                object
# Calculated host listings count    float64
# Reviews per Month                 float64
# Geolocation                        object
# Features                           object
# Length: 71, dtype: object

# %%
data['Price']
# Out:
# 0         58.0
# 1         70.0
# 2         70.0
# 3        229.0
# 4        149.0
# 5        106.0
# 6         52.0
# 7         45.0
# 8         80.0
# 9        795.0
# 10       100.0
# 11        64.0
# 12        90.0
# 13        94.0
# 14       115.0
# 15       169.0
# 16        94.0
# 17       200.0
# 18        65.0
# 19        24.0
# 20        40.0
# 21       129.0
# 22       185.0
# 23       188.0
# 24        90.0
# 25        55.0
# 26       100.0
# 27       229.0
# 28       100.0
# 29       106.0
#          ...
# 14750     35.0
# 14751     20.0
# 14752     22.0
# 14753     16.0
# 14754     35.0
# 14755     25.0
# 14756     50.0
# 14757     16.0
# 14758    226.0
# 14759    280.0
# 14760    162.0
# 14761    163.0
# 14762    120.0
# 14763     92.0
# 14764     40.0
# 14765    240.0
# 14766    120.0
# 14767     95.0
# 14768    950.0
# 14769     79.0
# 14770     90.0
# 14771    160.0
# 14772    196.0
# 14773    260.0
# 14774     40.0
# 14775     90.0
# 14776     75.0
# ...
